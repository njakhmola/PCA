# %%
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv ")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
df1 = df.drop(['date'], axis =1)
df1.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df1.isnull().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df2 = (df1-df1.min())/(df1.max()-df1.min())
df2.head()
# Out:
#          id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  0.720103  0.019266  0.090909    0.12500     0.067170  0.003108     0.0
# 1  0.647853  0.060721  0.090909    0.28125     0.172075  0.004072     0.4
# 2  0.568795  0.013770  0.060606    0.12500     0.036226  0.005743     0.0
# 3  0.251157  0.069377  0.121212    0.37500     0.126038  0.002714     0.0
# 4  0.197333  0.057049  0.090909    0.25000     0.104906  0.004579     0.0
#
#    waterfront  view  condition     grade  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0        0.5  0.500000    0.097588       0.000000  0.478261
# 1         0.0   0.0        0.5  0.500000    0.206140       0.082988  0.443478
# 2         0.0   0.0        0.5  0.416667    0.052632       0.000000  0.286957
# 3         0.0   0.0        1.0  0.500000    0.083333       0.188797  0.565217
# 4         0.0   0.0        0.5  0.583333    0.152412       0.000000  0.756522
#
#    yr_renovated   zipcode       lat      long  sqft_living15  sqft_lot15
# 0      0.000000  0.893939  0.571498  0.217608       0.161934    0.005742
# 1      0.988089  0.626263  0.908959  0.166113       0.222165    0.008027
# 2      0.000000  0.136364  0.936143  0.237542       0.399415    0.008513
# 3      0.000000  0.681818  0.586939  0.104651       0.165376    0.004996
# 4      0.000000  0.368687  0.741354  0.393688       0.241094    0.007871

# %%
sns.kdeplot(df2['bathrooms'], shade =True, c= 'b')
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
a= np.power(df2['bathrooms'],(1/2))
sns.kdeplot(a, shade =True, c= 'b')
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
a = np.log(df2['bathrooms'])
sns.kdeplot(a,shade = True, c= 'b')
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
a= np.power(df2['bedrooms'],(1/3))
sns.kdeplot(a, shade =True, c= 'b')#Normalization by cube
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
df_n= df2.select_dtypes(include = [np.number])
df_l = df_n.loc[:,['sqft_living','price']]
df_l.head()
# Out:
#    sqft_living     price
# 0     0.067170  0.019266
# 1     0.172075  0.060721
# 2     0.036226  0.013770
# 3     0.126038  0.069377
# 4     0.104906  0.057049

# %%
x = np.array(df_l['sqft_living']).reshape(21613,1)
y = np.array(df_l['price']).reshape(21613,1)
x
y
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.30)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (15129, 1) (15129, 1)
# (6484, 1) (6484, 1)

# %%
reg = LinearRegression()
reg.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([[0.00231214]])

# %%
reg.intercept_
# Out:
# array([0.06086298])

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([[0.0611544 ],
#        [0.06103225],
#        [0.06103748],
#        ...,
#        [0.06098862],
#        [0.06133937],
#        [0.06155401]])

# %%
a = pd.DataFrame({"actual":[Y_test], "prediction":[Y_pred]})
a
# Out:
#                                               actual  \
# 0  [[0.04721311475409836], [0.043278688524590166]...
#
#                                           prediction
# 0  [[0.06115439861531731], [0.06103224758323702],...

# %%
a = pd.DataFrame({"actual":list(Y_test), "prediction":list(Y_pred)})
a
# Out:
#                       actual              prediction
# 0      [0.04721311475409836]   [0.06115439861531731]
# 1     [0.043278688524590166]   [0.06103224758323702]
# 2      [0.04786885245901639]   [0.06103748262746903]
# 3                    [0.032]   [0.06107063790760511]
# 4      [0.08852459016393442]    [0.0611927889396854]
# 5      [0.07449206557377049]   [0.06112124333518123]
# 6      [0.05376393442622951]   [0.06110379318774119]
# 7      [0.03180327868852459]  [0.061025267524261004]
# 8      [0.04655737704918033]  [0.061266079558933574]
# 9      [0.05639344262295082]   [0.06099734728835694]
# 10     [0.05099383606557377]   [0.06137950551729384]
# 11    [0.057704918032786885]   [0.06116661371852534]
# 12     [0.04721311475409836]  [0.061157888644805314]
# 13    [0.024262295081967214]  [0.061058946308820285]
# 14     [0.04124590163934426]   [0.06132890008971772]
# 15      [0.1580327868852459]   [0.06133762516343774]
# 16     [0.02622950819672131]   [0.06094674186078082]
# 17     [0.06885245901639345]  [0.061250374426237535]
# 18    [0.020327868852459016]   [0.06107412793709312]
# 19     [0.02281967213114754]   [0.06103922764221304]
# 20      [0.0740983606557377]   [0.06107761796658113]
# 21     [0.03121311475409836]   [0.06101828746528499]
# 22    [0.033049180327868855]   [0.06109681312876517]
# 23     [0.04852459016393443]   [0.06129923483906965]
# 24     [0.03409836065573771]  [0.061072382922349115]
# 25     [0.16064131147540983]  [0.061487696431422094]
# 26     [0.07016393442622951]   [0.06119627896917341]
# 27     [0.10819672131147541]   [0.06147722634295807]
# 28     [0.09495081967213115]   [0.06122943424930948]
# 29     [0.03540983606557377]  [0.060936271772316794]
# ...                      ...                     ...
# 6454   [0.05573770491803279]   [0.06097466209668489]
# 6455  [0.028065573770491802]   [0.06100258233258895]
# 6456   [0.03344262295081967]  [0.061342860207669755]
# 6457   [0.10426229508196722]   [0.06159675985292235]
# 6458   [0.08195409836065574]  [0.061194533954429406]
# 6459   [0.08354098360655737]    [0.0614056807384539]
# 6460   [0.21508196721311476]   [0.06159588734555035]
# 6461   [0.04524590163934426]   [0.06100432734733296]
# 6462   [0.06115908196721311]   [0.06117184876275735]
# 6463   [0.11318032786885246]   [0.06135158528138977]
# 6464   [0.06688524590163934]    [0.0611090282319732]
# 6465  [0.028721311475409836]    [0.0611090282319732]
# 6466   [0.01639344262295082]   [0.06095721194924485]
# 6467   [0.04878688524590164]   [0.06094499684603682]
# 6468                  [0.08]  [0.061295744809581644]
# 6469   [0.02622950819672131]  [0.061072382922349115]
# 6470   [0.05180327868852459]  [0.061187553895453384]
# 6471   [0.06360655737704918]   [0.06105144274542107]
# 6472   [0.02537704918032787]   [0.06095023189026883]
# 6473   [0.06518032786885246]  [0.061224199205077476]
# 6474  [0.019672131147540985]   [0.06104097265695704]
# 6475   [0.05310819672131147]  [0.061075872951837126]
# 6476   [0.01980327868852459]    [0.0609816421556609]
# 6477   [0.05893770491803279]   [0.06115963365954932]
# 6478   [0.05573770491803279]  [0.061264334544189565]
# 6479  [0.051147540983606556]   [0.06128597272701522]
# 6480   [0.03829508196721312]   [0.06112996840890125]
# 6481   [0.03186885245901639]   [0.06098862221463692]
# 6482    [0.1055672131147541]  [0.061339370178181744]
# 6483    [0.3114754098360656]   [0.06155400699169425]
#
# [6484 rows x 2 columns]

# %%
from sklearn import metrics
print(metrics.mean_squared_error(Y_test,Y_pred))
# Out:
# 0.0023722805862968627
