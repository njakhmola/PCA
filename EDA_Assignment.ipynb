# %% [markdown]
# # Answer 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %% [markdown]
# # Answer 2

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# 5      False  False  False     False      False        False     False
# 6      False  False  False     False      False        False     False
# 7      False  False  False     False      False        False     False
# 8      False  False  False     False      False        False     False
# 9      False  False  False     False      False        False     False
# 10     False  False  False     False      False        False     False
# 11     False  False  False     False      False        False     False
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.fillna(df.mean())
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %% [markdown]
# # Answer 3

# %% [markdown]
# # Univariate Analysis

# %%
df1 = df.head()
df1
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
sns.boxplot(df1['price'])

# %%
sns.distplot(df1['price'],kde = True)
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(df1['sqft_living'])

# %%
sns.boxplot(df1['bathrooms'])

# %%
sns.boxplot(df1['price'])

# %%
sns.countplot(df1['waterfront'])

# %%
sns.countplot(df1['sqft_above'])

# %%
sns.countplot(df1['price'])

# %%
sns.kdeplot(df['bedrooms'], shade =True, c= 'r')
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
sns.kdeplot(df['floors'], shade =True, c= 'b')
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2446: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %% [markdown]
# # Answer4

# %% [markdown]
# # Bivariate Analysis

# %%
sns.jointplot(df1['bedrooms'], df1['bathrooms'])
# Out:
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\nidhi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(hue='sqft_living15', x='bathrooms',data=df1)

# %%
sns.countplot(hue='bedrooms', x='bathrooms',data=df1)

# %%
sns.barplot(x='sqft_lot',y='sqft_above',hue='sqft_living15',data=df1)

# %%
plt.scatter(df1['bedrooms'], df1['bathrooms'])

# %%
plt.scatter(df1['sqft_living15'], df1['sqft_lot15'])

# %%
sns.stripplot(x='sqft_lot',y='sqft_above',hue='sqft_living15',data =df1)

# %% [markdown]
# # Answer5

# %%
plt.figure(figsize=(11,7))
sns.heatmap(df1.corr())

# %%
sns.boxplot(df1[['bathrooms','bedrooms','sqft_living','sqft_lot','floors','view']])

# %% [markdown]
# # Answer 6

# %%
#Three most interesting graphs

# %%
sns.boxplot(df1['price'])

# %%
#The above graph I choose for the uni-variate data as this shows the price and the graph is left skewed

# %%
plt.scatter(df1['sqft_living15'], df1['sqft_lot15'])

# %%
#For the bi-variate analysis I choose this graph because it shows the sqft_living  on the x-axis and sqft_lot15 on the y-axis.
#Scatter Plots are usually used to represent the correlation between two or more variables. It also helps in identifying Outliers,
#if any.

# %%
plt.figure(figsize=(11,7))
sns.heatmap(df1.corr())

# %%
#heatmap gives the co-realtion between all the variables.
#sns.heatmap() is an Axes-level function and will draw the heatmap into the currently-active Area.
#heatmap Plot rectangular data as a color-encoded matrix.
